# %%
# =========================================================
# FRAMEWORK MANUAL — BASE ESTRUTURAL
# IMDb + Hubara como primeiro caso
# =========================================================

from dataclasses import dataclass, field
from typing import Dict, List, Optional, Any
import pandas as pd


# ---------------------------------------------------------
# 1) Especificação do cenário
# ---------------------------------------------------------
# Representa o "mundo" que será testado:
# - nome do dataset
# - entidades
# - relacionamentos
# - queries do workload
#
# Exemplo:
# dataset = IMDb
# entities = User, Movie, Rating, ...
@dataclass
class ScenarioSpec:
    name: str
    description: str
    entities: List[str]
    relationships: List[Dict[str, Any]]
    workload_queries: List[Dict[str, Any]]


# ---------------------------------------------------------
# 2) Fragmento recomendado
# ---------------------------------------------------------
# Cada fragmento é um grupo de entidades que será alocado
# em um tipo/modelo de banco.
#
# Exemplo:
# Fragmento 1 = ['User'] -> relational
# Fragmento 2 = ['Movie', 'Genre', ...] -> column
@dataclass
class FragmentSpec:
    name: str
    entities: List[str]
    model: str   # relational, document, column, graph, etc.
    notes: str = ""


# ---------------------------------------------------------
# 3) Recomendação final
# ---------------------------------------------------------
# Representa a saída final de um método como o Hubara.
#
# Exemplo:
# recommendation_name = "Hubara IMDb"
# fragments = [FragmentSpec(...), FragmentSpec(...)]
@dataclass
class RecommendationSpec:
    recommendation_name: str
    source_method: str
    source_dataset: str
    fragments: List[FragmentSpec]


# ---------------------------------------------------------
# 4) Banco físico concreto
# ---------------------------------------------------------
# Aqui diferenciamos "modelo" de "produto".
#
# Exemplo:
# model = relational
# engine = PostgreSQL
#
# ou:
# model = document
# engine = MongoDB
@dataclass
class PhysicalDBSpec:
    model: str
    engine: str
    host: str = "localhost"
    port: Optional[int] = None
    database_name: Optional[str] = None
    username: Optional[str] = None
    password: Optional[str] = None


# ---------------------------------------------------------
# 5) Plano de materialização
# ---------------------------------------------------------
# Traduz a recomendação abstrata para bancos concretos.
#
# Exemplo:
# fragment User -> PostgreSQL
# fragment Content -> Cassandra
@dataclass
class MaterializationPlan:
    scenario_name: str
    recommendation_name: str
    fragment_to_db: Dict[str, PhysicalDBSpec]


# ---------------------------------------------------------
# 6) Especificação de uma query do benchmark
# ---------------------------------------------------------
# Aqui vamos guardar:
# - nome da query
# - tipo
# - entidades tocadas
# - texto abstrato
#
# Mais tarde, podemos ter versões por banco:
# sql_text, mongo_text, cypher_text, etc.
@dataclass
class BenchmarkQuery:
    name: str
    query_type: str
    entities_involved: List[str]
    abstract_query: str
    expected_fragment: Optional[str] = None
    expected_db_model: Optional[str] = None


# ---------------------------------------------------------
# 7) Especificação do workload
# ---------------------------------------------------------
@dataclass
class WorkloadSpec:
    name: str
    description: str
    queries: List[BenchmarkQuery]
    repetitions: int = 10


# ---------------------------------------------------------
# 8) Resultado de execução de uma query
# ---------------------------------------------------------
@dataclass
class QueryExecutionResult:
    query_name: str
    fragment_name: str
    db_engine: str
    run_id: int
    benchmark_phase: str   # "cold" ou "hot"
    latency_ms: float
    success: bool
    error_message: Optional[str] = None

# ---------------------------------------------------------
# 9) Resultado consolidado do benchmark
# ---------------------------------------------------------
@dataclass
class BenchmarkResult:
    scenario_name: str
    recommendation_name: str
    query_results: List[QueryExecutionResult] = field(default_factory=list)

    def to_dataframe(self) -> pd.DataFrame:
        return pd.DataFrame([
            {
                "scenario_name": self.scenario_name,
                "recommendation_name": self.recommendation_name,
                "query_name": r.query_name,
                "fragment_name": r.fragment_name,
                "db_engine": r.db_engine,
                "run_id": r.run_id,
                "benchmark_phase": r.benchmark_phase,
                "latency_ms": r.latency_ms,
                "success": r.success,
                "error_message": r.error_message,
            }
            for r in self.query_results
        ])

# %%
# =========================================================
# INSTÂNCIA 1 — CENÁRIO IMDb + RECOMENDAÇÃO HUBARA
# =========================================================

# ---------------------------------------------------------
# 1) Cenário IMDb
# ---------------------------------------------------------
imdb_scenario = ScenarioSpec(
    name="IMDb",
    description="IMDb-like scenario based on the Hubara paper",
    entities=[
        "Person",
        "User",
        "Genre",
        "Role",
        "Rate",
        "WatchItem",
        "Series",
        "Movie",
        "Episode",
    ],
    relationships=[
        {"source": "Person", "target": "Role", "name": "acts_in_via_role"},
        {"source": "Role", "target": "WatchItem", "name": "role_of_watchitem"},
        {"source": "Person", "target": "WatchItem", "name": "directs"},
        {"source": "Person", "target": "WatchItem", "name": "produces"},
        {"source": "Genre", "target": "WatchItem", "name": "has_genre"},
        {"source": "User", "target": "Rate", "name": "rates"},
        {"source": "Rate", "target": "WatchItem", "name": "rate_of_watchitem"},
        {"source": "Series", "target": "WatchItem", "name": "series_is_watchitem"},
        {"source": "Movie", "target": "WatchItem", "name": "movie_is_watchitem"},
        {"source": "Episode", "target": "WatchItem", "name": "episode_is_watchitem"},
        {"source": "Series", "target": "Episode", "name": "series_contains_episode"},
    ],
    workload_queries=[
        {
            "name": "Q1_Login",
            "type": "select",
            "entities": ["User"],
            "abstract_query": "RETURN password FROM User WHERE username = ?"
        },
        {
            "name": "Q2_SimpleSearch",
            "type": "select",
            "entities": ["WatchItem"],
            "abstract_query": "RETURN ALL FROM WatchItem WHERE title = ?"
        },
        {
            "name": "Q3_AddEntitiesAndRelationships",
            "type": "insert",
            "entities": ["Person", "WatchItem", "Role"],
            "abstract_query": "INSERT Person and connect Person with WatchItem"
        },
        {
            "name": "Q4_Recommendation",
            "type": "select",
            "entities": ["WatchItem", "Genre", "Movie", "Series", "Episode"],
            "abstract_query": "Recommendation query by genre and type"
        },
        {
            "name": "Q5_AllPersonsOfTypeForWatchItem",
            "type": "select",
            "entities": ["WatchItem", "Person", "Role"],
            "abstract_query": "RETURN Person.ALL FROM WatchItem, Person WHERE title = ? AND rel = Actor"
        },
    ]
)


# ---------------------------------------------------------
# 2) Recomendação Hubara para IMDb
# ---------------------------------------------------------
# Resultado que você reproduziu:
# - Fragmento de conteúdo -> Column
# - Fragmento de User -> RDBMS
hubara_imdb_recommendation = RecommendationSpec(
    recommendation_name="Hubara_IMDb_Recommendation",
    source_method="Hubara",
    source_dataset="IMDb",
    fragments=[
        FragmentSpec(
            name="ContentFragment",
            entities=["Episode", "Genre", "Movie", "Person", "Rate", "Role", "Series", "WatchItem"],
            model="column",
            notes="Recommended by the implemented Hubara workflow"
        ),
        FragmentSpec(
            name="UserFragment",
            entities=["User"],
            model="relational",
            notes="Recommended by the implemented Hubara workflow"
        ),
    ]
)


# ---------------------------------------------------------
# 3) Plano físico concreto
# ---------------------------------------------------------
# Aqui você escolhe quais produtos concretos representam
# cada modelo lógico.
#
# Exemplo inicial:
# relational -> PostgreSQL
# column -> Cassandra
#
# Você pode trocar Cassandra por outro depois.
hubara_imdb_materialization = MaterializationPlan(
    scenario_name="IMDb",
    recommendation_name="Hubara_IMDb_Recommendation",
    fragment_to_db={
        "UserFragment": PhysicalDBSpec(
            model="relational",
            engine="PostgreSQL",
            host="127.0.0.1",
            port=55432,
            database_name="imdb_user_db",
            username="postgres",
            password="postgres"
        ),
        "ContentFragment": PhysicalDBSpec(
            model="column",
            engine="Cassandra",
            host="127.0.0.1",
            port=59042,
            database_name="imdb_content_db"
        ),
    }
)


# ---------------------------------------------------------
# 4) Workload do benchmark
# ---------------------------------------------------------
imdb_workload = WorkloadSpec(
    name="IMDb_Hubara_Workload",
    description="Benchmark workload for the IMDb scenario using the Hubara recommendation",
    queries=[
        BenchmarkQuery(
            name="Q1_Login",
            query_type="select",
            entities_involved=["User"],
            abstract_query="RETURN password FROM User WHERE username = ?",
            expected_fragment="UserFragment",
            expected_db_model="relational"
        ),
        BenchmarkQuery(
            name="Q2_SimpleSearch",
            query_type="select",
            entities_involved=["WatchItem"],
            abstract_query="RETURN ALL FROM WatchItem WHERE title = ?",
            expected_fragment="ContentFragment",
            expected_db_model="column"
        ),
        BenchmarkQuery(
            name="Q3_AddEntitiesAndRelationships",
            query_type="insert",
            entities_involved=["Person", "WatchItem", "Role"],
            abstract_query="INSERT Person and connect Person with WatchItem",
            expected_fragment="ContentFragment",
            expected_db_model="column"
        ),
        BenchmarkQuery(
            name="Q4_Recommendation",
            query_type="select",
            entities_involved=["WatchItem", "Genre", "Movie", "Series", "Episode"],
            abstract_query="Recommendation query by genre and type",
            expected_fragment="ContentFragment",
            expected_db_model="column"
        ),
        BenchmarkQuery(
            name="Q5_AllPersonsOfTypeForWatchItem",
            query_type="select",
            entities_involved=["WatchItem", "Person", "Role"],
            abstract_query="RETURN Person.ALL FROM WatchItem, Person WHERE title = ? AND rel = Actor",
            expected_fragment="ContentFragment",
            expected_db_model="column"
        ),
    ],
    repetitions=10
)

# %%
# =========================================================
# VISUALIZAÇÃO DAS ESTRUTURAS
# =========================================================

scenario_entities_df = pd.DataFrame({"entity": imdb_scenario.entities})

scenario_relationships_df = pd.DataFrame(imdb_scenario.relationships)

recommendation_df = pd.DataFrame([
    {
        "fragment": frag.name,
        "entities": frag.entities,
        "model": frag.model,
        "notes": frag.notes
    }
    for frag in hubara_imdb_recommendation.fragments
])

materialization_df = pd.DataFrame([
    {
        "fragment": fragment_name,
        "model": dbspec.model,
        "engine": dbspec.engine,
        "host": dbspec.host,
        "port": dbspec.port,
        "database_name": dbspec.database_name
    }
    for fragment_name, dbspec in hubara_imdb_materialization.fragment_to_db.items()
])

workload_df = pd.DataFrame([
    {
        "query_name": q.name,
        "query_type": q.query_type,
        "entities_involved": q.entities_involved,
        "expected_fragment": q.expected_fragment,
        "expected_db_model": q.expected_db_model,
        "abstract_query": q.abstract_query
    }
    for q in imdb_workload.queries
])

print("Entities")
display(scenario_entities_df)

print("Relationships")
display(scenario_relationships_df)

print("Recommendation")
display(recommendation_df)

print("Materialization plan")
display(materialization_df)

print("Workload")
display(workload_df)
# Out:
# Entities
#       entity
# 0     Person
# 1       User
# 2      Genre
# 3       Role
# 4       Rate
# 5  WatchItem
# 6     Series
# 7      Movie
# 8    Episode
# Relationships
#      source     target                     name
# 0    Person       Role         acts_in_via_role
# 1      Role  WatchItem        role_of_watchitem
# 2    Person  WatchItem                  directs
# 3    Person  WatchItem                 produces
# 4     Genre  WatchItem                has_genre
# 5      User       Rate                    rates
# 6      Rate  WatchItem        rate_of_watchitem
# 7    Series  WatchItem      series_is_watchitem
# 8     Movie  WatchItem       movie_is_watchitem
# 9   Episode  WatchItem     episode_is_watchitem
# 10   Series    Episode  series_contains_episode
# Recommendation
#           fragment                                           entities  \
# 0  ContentFragment  [Episode, Genre, Movie, Person, Rate, Role, Se...
# 1     UserFragment                                             [User]
#
#         model                                           notes
# 0      column  Recommended by the implemented Hubara workflow
# 1  relational  Recommended by the implemented Hubara workflow
# Materialization plan
#           fragment       model      engine       host  port    database_name
# 0     UserFragment  relational  PostgreSQL  localhost  5432     imdb_user_db
# 1  ContentFragment      column   Cassandra  localhost  9042  imdb_content_db
# Workload
#                         query_name query_type  \
# 0                         Q1_Login     select
# 1                  Q2_SimpleSearch     select
# 2   Q3_AddEntitiesAndRelationships     insert
# 3                Q4_Recommendation     select
# 4  Q5_AllPersonsOfTypeForWatchItem     select
#
#                             entities_involved expected_fragment  \
# 0                                      [User]      UserFragment
# 1                                 [WatchItem]   ContentFragment
# 2                   [Person, WatchItem, Role]   ContentFragment
# 3  [WatchItem, Genre, Movie, Series, Episode]   ContentFragment
# 4                   [WatchItem, Person, Role]   ContentFragment
#
#   expected_db_model                                     abstract_query
# 0        relational       RETURN password FROM User WHERE username = ?
# 1            column          RETURN ALL FROM WatchItem WHERE title = ?
# 2            column    INSERT Person and connect Person with WatchItem
# 3            column             Recommendation query by genre and type
# 4            column  RETURN Person.ALL FROM WatchItem, Person WHERE...

# %%
# =========================================================
# BLOCO 1 — GERADOR DE DADOS SINTÉTICOS IMDb
# =========================================================

from dataclasses import dataclass, field
from typing import Dict, List
import pandas as pd

@dataclass
class ScenarioDataBundle:
    dataset_name: str
    tables: Dict[str, pd.DataFrame] = field(default_factory=dict)

    def table_names(self) -> List[str]:
        return list(self.tables.keys())

    def summary(self) -> pd.DataFrame:
        return pd.DataFrame([
            {
                "table_name": name,
                "rows": len(df),
                "columns": list(df.columns)
            }
            for name, df in self.tables.items()
        ]).sort_values("table_name").reset_index(drop=True)

# %%
# =========================================================
# BLOCO 2 — GERADOR DE DADOS SINTÉTICOS IMDb (CORRIGIDO)
# =========================================================

import random
import numpy as np
import pandas as pd

def generate_imdb_synthetic_data(
    n_users: int = 100,
    n_persons: int = 120,
    n_watchitems: int = 80,
    n_genres: int = 10,
    seed: int = 42
) -> "ScenarioDataBundle":
    """
    Gera um dataset sintético simplificado para o cenário IMDb.
    """

    rng = random.Random(seed)
    np_rng = np.random.default_rng(seed)

    # 1) USERS
    users = pd.DataFrame([
        {
            "user_id": i,
            "username": f"user_{i}",
            "password": f"pass_{i}",
            "email": f"user_{i}@mail.com",
            "last_login": f"2026-01-{(i % 28) + 1:02d}"
        }
        for i in range(1, n_users + 1)
    ])

    # 2) PERSONS
    persons = pd.DataFrame([
        {
            "person_id": i,
            "name": f"Person {i}",
            "date_of_birth": f"{1970 + (i % 30)}-{(i % 12) + 1:02d}-{(i % 28) + 1:02d}",
            "gender": "M" if i % 2 == 0 else "F"
        }
        for i in range(1, n_persons + 1)
    ])

    # 3) GENRES
    genre_names = [
        "Action", "Drama", "Comedy", "Thriller", "SciFi",
        "Fantasy", "Romance", "Crime", "Adventure", "Mystery"
    ][:n_genres]

    genres = pd.DataFrame([
        {"genre_id": i + 1, "name": genre_names[i]}
        for i in range(len(genre_names))
    ])

    # 4) WATCHITEMS
    item_types = np_rng.choice(
        ["Movie", "Series", "Episode"],
        size=n_watchitems,
        p=[0.45, 0.20, 0.35]
    )

    watchitems_rows = []
    for i in range(1, n_watchitems + 1):
        genre_id = int(np_rng.integers(1, len(genres) + 1))
        release_year = int(np_rng.integers(1990, 2026))

        watchitems_rows.append({
            "watchitem_id": i,
            "title": f"Title {i}",
            "release_year": release_year,
            "avg_rating": round(float(np_rng.uniform(1.0, 10.0)), 2),
            "genre_id": genre_id,
            "item_type": item_types[i - 1]
        })

    watchitems = pd.DataFrame(watchitems_rows)

    # 5) MOVIES
    movies = watchitems[watchitems["item_type"] == "Movie"][["watchitem_id"]].copy()
    movies["length_min"] = np_rng.integers(80, 181, size=len(movies))
    movies["media"] = np_rng.choice(["Cinema", "Streaming", "TV"], size=len(movies))
    movies["income"] = np_rng.integers(100000, 1000000000, size=len(movies))

    # 6) SERIES
    series = watchitems[watchitems["item_type"] == "Series"][["watchitem_id"]].copy()
    series["seasons"] = np_rng.integers(1, 8, size=len(series))
    series["network"] = np_rng.choice(["HBO", "Netflix", "Prime", "Disney"], size=len(series))

    # 7) EPISODES
    episodes = watchitems[watchitems["item_type"] == "Episode"][["watchitem_id"]].copy()
    episodes["season"] = np_rng.integers(1, 8, size=len(episodes))
    episodes["episode_number"] = np_rng.integers(1, 25, size=len(episodes))
    episodes["length_min"] = np_rng.integers(20, 61, size=len(episodes))

    if len(series) > 0 and len(episodes) > 0:
        series_ids = series["watchitem_id"].tolist()
        episodes["series_watchitem_id"] = [rng.choice(series_ids) for _ in range(len(episodes))]
    else:
        episodes["series_watchitem_id"] = None

    # 8) ROLES
    role_types = ["Actor", "Director", "Producer"]

    roles_rows = []
    role_id = 1
    for watchitem_id in watchitems["watchitem_id"]:
        n_links = int(np_rng.integers(2, 6))
        chosen_persons = rng.sample(persons["person_id"].tolist(), k=min(n_links, len(persons)))

        for person_id in chosen_persons:
            roles_rows.append({
                "role_id": role_id,
                "person_id": person_id,
                "watchitem_id": watchitem_id,
                "role_type": rng.choice(role_types)
            })
            role_id += 1

    roles = pd.DataFrame(roles_rows)

    # 9) RATES
    rates_rows = []
    rate_id = 1

    for user_id in users["user_id"]:
        n_user_ratings = int(np_rng.integers(2, 10))
        chosen_items = rng.sample(
            watchitems["watchitem_id"].tolist(),
            k=min(n_user_ratings, len(watchitems))
        )

        for watchitem_id in chosen_items:
            rating_value = int(np_rng.integers(1, 11))
            verbal = (
                "Excellent" if rating_value >= 9 else
                "Good" if rating_value >= 7 else
                "Average" if rating_value >= 5 else
                "Bad"
            )

            rates_rows.append({
                "rate_id": rate_id,
                "user_id": user_id,
                "watchitem_id": watchitem_id,
                "rating": rating_value,
                "verbal_rating": verbal
            })
            rate_id += 1

    rates = pd.DataFrame(rates_rows)

    return ScenarioDataBundle(
        dataset_name="IMDb",
        tables={
            "users": users,
            "persons": persons,
            "genres": genres,
            "watchitems": watchitems,
            "movies": movies,
            "series": series,
            "episodes": episodes,
            "roles": roles,
            "rates": rates,
        }
    )

# %%
# =========================================================
# BLOCO 3 — GERAR O DATASET IMDb SINTÉTICO
# =========================================================

import pandas as pd

# Checagem simples para evitar erro confuso se o bloco anterior não tiver rodado
if "generate_imdb_synthetic_data" not in globals():
    raise NameError(
        "A função 'generate_imdb_synthetic_data' não está definida. "
        "Rode primeiro o bloco anterior que cria essa função."
    )

# Gera o dataset sintético
imdb_data_bundle = generate_imdb_synthetic_data(
    n_users=100,
    n_persons=120,
    n_watchitems=80,
    n_genres=10,
    seed=42
)

# Mostra um resumo das tabelas geradas
print("Resumo das tabelas geradas:")
display(imdb_data_bundle.summary())

# Mostra algumas amostras para inspeção
print("Prévia: users")
display(imdb_data_bundle.tables["users"].head())

print("Prévia: watchitems")
display(imdb_data_bundle.tables["watchitems"].head())

print("Prévia: roles")
display(imdb_data_bundle.tables["roles"].head())

print("Prévia: rates")
display(imdb_data_bundle.tables["rates"].head())
# Out:
# Resumo das tabelas geradas:
#    table_name  rows                                            columns
# 0    episodes    31  [watchitem_id, season, episode_number, length_...
# 1      genres    10                                   [genre_id, name]
# 2      movies    34          [watchitem_id, length_min, media, income]
# 3     persons   120           [person_id, name, date_of_birth, gender]
# 4       rates   547  [rate_id, user_id, watchitem_id, rating, verba...
# 5       roles   290      [role_id, person_id, watchitem_id, role_type]
# 6      series    15                   [watchitem_id, seasons, network]
# 7       users   100   [user_id, username, password, email, last_login]
# 8  watchitems    80  [watchitem_id, title, release_year, avg_rating...
# Prévia: users
#    user_id username password            email  last_login
# 0        1   user_1   pass_1  user_1@mail.com  2026-01-02
# 1        2   user_2   pass_2  user_2@mail.com  2026-01-03
# 2        3   user_3   pass_3  user_3@mail.com  2026-01-04
# 3        4   user_4   pass_4  user_4@mail.com  2026-01-05
# 4        5   user_5   pass_5  user_5@mail.com  2026-01-06
# Prévia: watchitems
#    watchitem_id    title  release_year  avg_rating  genre_id item_type
# 0             1  Title 1          2013        4.66        10   Episode
# 1             2  Title 2          2019        2.50         5     Movie
# 2             3  Title 3          1990        1.81         4   Episode
# 3             4  Title 4          2016        5.16         8   Episode
# 4             5  Title 5          1995        5.51         8     Movie
# Prévia: roles
#    role_id  person_id  watchitem_id role_type
# 0        1         54             1  Producer
# 1        2         29             1  Director
# 2        3         58             1     Actor
# 3        4         98             2  Producer
# 4        5        104             2  Director
# Prévia: rates
#    rate_id  user_id  watchitem_id  rating verbal_rating
# 0        1        1            26       1           Bad
# 1        2        1            47       1           Bad
# 2        3        1            56       5       Average
# 3        4        1             9       8          Good
# 4        5        1            43       9     Excellent

# %%
# =========================================================
# BLOCO 4 — PARTICIONAR OS DADOS PELOS FRAGMENTOS
# =========================================================

# Mapa simples: qual tabela lógica pertence a qual entidade conceitual
LOGICAL_TABLE_TO_ENTITY = {
    "users": "User",
    "persons": "Person",
    "genres": "Genre",
    "watchitems": "WatchItem",
    "movies": "Movie",
    "series": "Series",
    "episodes": "Episode",
    "roles": "Role",
    "rates": "Rate",
}


def split_bundle_by_recommendation(
    bundle: ScenarioDataBundle,
    recommendation: RecommendationSpec
) -> Dict[str, Dict[str, pd.DataFrame]]:
    """
    Retorna:
    {
        "UserFragment": {
            "users": df
        },
        "ContentFragment": {
            "persons": df,
            "genres": df,
            ...
        }
    }
    """

    fragment_map = {frag.name: set(frag.entities) for frag in recommendation.fragments}
    result = {frag.name: {} for frag in recommendation.fragments}

    for table_name, df in bundle.tables.items():
        entity_name = LOGICAL_TABLE_TO_ENTITY[table_name]

        for fragment_name, fragment_entities in fragment_map.items():
            if entity_name in fragment_entities:
                result[fragment_name][table_name] = df.copy()
                break

    return result

# %%
# =========================================================
# BLOCO 5 — EXECUTAR PARTICIONAMENTO DOS DADOS
# =========================================================

fragmented_data = split_bundle_by_recommendation(
    bundle=imdb_data_bundle,
    recommendation=hubara_imdb_recommendation
)

for fragment_name, tables_dict in fragmented_data.items():
    print("\n" + "=" * 70)
    print(f"Fragmento: {fragment_name}")

    summary_df = pd.DataFrame([
        {
            "table_name": table_name,
            "rows": len(df),
            "columns": list(df.columns)
        }
        for table_name, df in tables_dict.items()
    ]).sort_values("table_name").reset_index(drop=True)

    display(summary_df)
# Out:
# ======================================================================
# Fragmento: ContentFragment
#    table_name  rows                                            columns
# 0    episodes    31  [watchitem_id, season, episode_number, length_...
# 1      genres    10                                   [genre_id, name]
# 2      movies    34          [watchitem_id, length_min, media, income]
# 3     persons   120           [person_id, name, date_of_birth, gender]
# 4       rates   547  [rate_id, user_id, watchitem_id, rating, verba...
# 5       roles   290      [role_id, person_id, watchitem_id, role_type]
# 6      series    15                   [watchitem_id, seasons, network]
# 7  watchitems    80  [watchitem_id, title, release_year, avg_rating...
# ======================================================================
# Fragmento: UserFragment
#   table_name  rows                                           columns
# 0      users   100  [user_id, username, password, email, last_login]

# %%
# =========================================================
# BLOCO 6 — PREPARAÇÃO DE PAYLOAD FÍSICO INICIAL
# =========================================================

@dataclass
class PhysicalLoadBundle:
    fragment_name: str
    db_model: str
    db_engine: str
    physical_tables: Dict[str, pd.DataFrame] = field(default_factory=dict)

    def summary(self) -> pd.DataFrame:
        return pd.DataFrame([
            {
                "physical_table": name,
                "rows": len(df),
                "columns": list(df.columns)
            }
            for name, df in self.physical_tables.items()
        ]).sort_values("physical_table").reset_index(drop=True)


def build_user_fragment_postgres_payload(fragment_tables: Dict[str, pd.DataFrame]) -> PhysicalLoadBundle:
    """
    Materialização simples do fragmento User para PostgreSQL.
    """
    users = fragment_tables["users"].copy()

    return PhysicalLoadBundle(
        fragment_name="UserFragment",
        db_model="relational",
        db_engine="PostgreSQL",
        physical_tables={
            "users": users
        }
    )


def build_content_fragment_cassandra_payload(fragment_tables: Dict[str, pd.DataFrame]) -> PhysicalLoadBundle:
    """
    Materialização inicial do fragmento de conteúdo para Cassandra.

    Aqui criamos não apenas tabelas "canônicas", mas também algumas
    tabelas orientadas ao workload, o que faz sentido em sistemas colunares.
    """

    persons = fragment_tables["persons"].copy()
    genres = fragment_tables["genres"].copy()
    watchitems = fragment_tables["watchitems"].copy()
    movies = fragment_tables["movies"].copy()
    series = fragment_tables["series"].copy()
    episodes = fragment_tables["episodes"].copy()
    roles = fragment_tables["roles"].copy()
    rates = fragment_tables["rates"].copy()

    # -----------------------------------------------------
    # 1) Tabela canônica de watchitems por título
    # Útil para Q2: simple search por title
    # -----------------------------------------------------
    watchitems_by_title = watchitems.copy()

    # -----------------------------------------------------
    # 2) Pessoas por watchitem
    # Útil para Q5: pessoas associadas a um item
    # -----------------------------------------------------
    persons_by_watchitem = (
        roles.merge(persons, on="person_id", how="left")
        [["watchitem_id", "person_id", "name", "role_type"]]
        .sort_values(["watchitem_id", "role_type", "person_id"])
        .reset_index(drop=True)
    )

    # -----------------------------------------------------
    # 3) Watchitems por gênero e tipo
    # Útil para Q4: recommendation query
    # -----------------------------------------------------
    watchitems_by_genre_type = (
        watchitems.merge(genres, on="genre_id", how="left")
        [["genre_id", "name", "item_type", "watchitem_id", "title", "release_year", "avg_rating"]]
        .rename(columns={"name": "genre_name"})
        .sort_values(["genre_id", "item_type", "release_year"])
        .reset_index(drop=True)
    )

    # -----------------------------------------------------
    # 4) Tabelas canônicas adicionais
    # -----------------------------------------------------
    return PhysicalLoadBundle(
        fragment_name="ContentFragment",
        db_model="column",
        db_engine="Cassandra",
        physical_tables={
            "persons": persons,
            "genres": genres,
            "watchitems": watchitems,
            "movies": movies,
            "series": series,
            "episodes": episodes,
            "roles": roles,
            "rates": rates,
            "watchitems_by_title": watchitems_by_title,
            "persons_by_watchitem": persons_by_watchitem,
            "watchitems_by_genre_type": watchitems_by_genre_type,
        }
    )

# %%
# =========================================================
# BLOCO 7 — CONSTRUIR PAYLOADS FÍSICOS
# =========================================================

user_payload = build_user_fragment_postgres_payload(fragmented_data["UserFragment"])
content_payload = build_content_fragment_cassandra_payload(fragmented_data["ContentFragment"])

print("Resumo do payload PostgreSQL:")
display(user_payload.summary())

print("Resumo do payload Cassandra:")
display(content_payload.summary())

print("Prévia: users (PostgreSQL)")
display(user_payload.physical_tables["users"].head())

print("Prévia: watchitems_by_title (Cassandra)")
display(content_payload.physical_tables["watchitems_by_title"].head())

print("Prévia: persons_by_watchitem (Cassandra)")
display(content_payload.physical_tables["persons_by_watchitem"].head())

print("Prévia: watchitems_by_genre_type (Cassandra)")
display(content_payload.physical_tables["watchitems_by_genre_type"].head())
# Out:
# Resumo do payload PostgreSQL:
#   physical_table  rows                                           columns
# 0          users   100  [user_id, username, password, email, last_login]
# Resumo do payload Cassandra:
#               physical_table  rows  \
# 0                   episodes    31
# 1                     genres    10
# 2                     movies    34
# 3                    persons   120
# 4       persons_by_watchitem   290
# 5                      rates   547
# 6                      roles   290
# 7                     series    15
# 8                 watchitems    80
# 9   watchitems_by_genre_type    80
# 10       watchitems_by_title    80
#
#                                               columns
# 0   [watchitem_id, season, episode_number, length_...
# 1                                    [genre_id, name]
# 2           [watchitem_id, length_min, media, income]
# 3            [person_id, name, date_of_birth, gender]
# 4          [watchitem_id, person_id, name, role_type]
# 5   [rate_id, user_id, watchitem_id, rating, verba...
# 6       [role_id, person_id, watchitem_id, role_type]
# 7                    [watchitem_id, seasons, network]
# 8   [watchitem_id, title, release_year, avg_rating...
# 9   [genre_id, genre_name, item_type, watchitem_id...
# 10  [watchitem_id, title, release_year, avg_rating...
# Prévia: users (PostgreSQL)
#    user_id username password            email  last_login
# 0        1   user_1   pass_1  user_1@mail.com  2026-01-02
# 1        2   user_2   pass_2  user_2@mail.com  2026-01-03
# 2        3   user_3   pass_3  user_3@mail.com  2026-01-04
# 3        4   user_4   pass_4  user_4@mail.com  2026-01-05
# 4        5   user_5   pass_5  user_5@mail.com  2026-01-06
# Prévia: watchitems_by_title (Cassandra)
#    watchitem_id    title  release_year  avg_rating  genre_id item_type
# 0             1  Title 1          2013        4.66        10   Episode
# 1             2  Title 2          2019        2.50         5     Movie
# 2             3  Title 3          1990        1.81         4   Episode
# 3             4  Title 4          2016        5.16         8   Episode
# 4             5  Title 5          1995        5.51         8     Movie
# Prévia: persons_by_watchitem (Cassandra)
#    watchitem_id  person_id        name role_type
# 0             1         58   Person 58     Actor
# 1             1         29   Person 29  Director
# 2             1         54   Person 54  Producer
# 3             2         21   Person 21  Director
# 4             2        104  Person 104  Director
# Prévia: watchitems_by_genre_type (Cassandra)
#    genre_id genre_name item_type  watchitem_id     title  release_year  \
# 0         1     Action   Episode            19  Title 19          2017
# 1         1     Action   Episode            53  Title 53          2017
# 2         1     Action   Episode            56  Title 56          2023
# 3         1     Action     Movie            15  Title 15          1993
# 4         1     Action     Movie            60  Title 60          1997
#
#    avg_rating
# 0        7.48
# 1        6.95
# 2        3.17
# 3        9.12
# 4        3.79

# %%
# =========================================================
# BLOCO A1.1 — UTILITÁRIOS DE EXPORTAÇÃO
# =========================================================

from pathlib import Path
import pandas as pd
import numpy as np
import json


# ---------------------------------------------------------
# 1) Criar diretório se não existir
# ---------------------------------------------------------
def ensure_dir(path: str | Path) -> Path:
    path = Path(path)
    path.mkdir(parents=True, exist_ok=True)
    return path


# ---------------------------------------------------------
# 2) Escapar strings para SQL/CQL
# ---------------------------------------------------------
def escape_sql_string(value: str) -> str:
    """
    Troca ' por '' para evitar quebrar INSERTs SQL/CQL.
    """
    return value.replace("'", "''")


# ---------------------------------------------------------
# 3) Converter valor Python/Pandas para literal SQL
# ---------------------------------------------------------
def to_sql_literal(value):
    """
    Exemplos:
    - 10        -> 10
    - 3.14      -> 3.14
    - "abc"     -> 'abc'
    - None/NaN  -> NULL
    """
    if pd.isna(value):
        return "NULL"
    if isinstance(value, (int, np.integer)):
        return str(int(value))
    if isinstance(value, (float, np.floating)):
        return str(float(value))
    if isinstance(value, bool):
        return "TRUE" if value else "FALSE"
    return f"'{escape_sql_string(str(value))}'"


# ---------------------------------------------------------
# 4) Converter valor Python/Pandas para literal CQL
# ---------------------------------------------------------
def to_cql_literal(value):
    """
    Para este caso inicial, usamos a mesma lógica básica do SQL.
    """
    if pd.isna(value):
        return "NULL"
    if isinstance(value, (int, np.integer)):
        return str(int(value))
    if isinstance(value, (float, np.floating)):
        return str(float(value))
    if isinstance(value, bool):
        return "true" if value else "false"
    return f"'{escape_sql_string(str(value))}'"


# ---------------------------------------------------------
# 5) Inferir tipo PostgreSQL simples a partir da coluna
# ---------------------------------------------------------
def infer_postgres_type(series: pd.Series) -> str:
    """
    Inferência simples e pragmática.
    """
    if pd.api.types.is_integer_dtype(series):
        return "BIGINT"
    if pd.api.types.is_float_dtype(series):
        return "DOUBLE PRECISION"
    if pd.api.types.is_bool_dtype(series):
        return "BOOLEAN"

    # Se tudo parece data ISO simples, poderíamos sofisticar depois.
    return "TEXT"


# ---------------------------------------------------------
# 6) Inferir tipo Cassandra simples a partir da coluna
# ---------------------------------------------------------
def infer_cassandra_type(series: pd.Series) -> str:
    """
    Inferência simples e pragmática.
    """
    if pd.api.types.is_integer_dtype(series):
        return "bigint"
    if pd.api.types.is_float_dtype(series):
        return "double"
    if pd.api.types.is_bool_dtype(series):
        return "boolean"

    return "text"


# ---------------------------------------------------------
# 7) Salvar texto em arquivo
# ---------------------------------------------------------
def write_text_file(path: str | Path, content: str) -> Path:
    path = Path(path)
    path.write_text(content, encoding="utf-8")
    return path

# %%
# =========================================================
# BLOCO A1.2 — EXPORTAR TABELAS FÍSICAS PARA CSV E JSON
# =========================================================

def export_bundle_to_csv_json(
    payload: PhysicalLoadBundle,
    base_output_dir: str | Path
) -> dict[str, list[Path]]:
    """
    Exporta cada tabela física do payload para:
    - CSV
    - JSON (records)

    Estrutura:
    base_output_dir/
        fragment_name/
            csv/
            json/
    """

    base_output_dir = ensure_dir(base_output_dir)
    fragment_dir = ensure_dir(base_output_dir / payload.fragment_name)
    csv_dir = ensure_dir(fragment_dir / "csv")
    json_dir = ensure_dir(fragment_dir / "json")

    exported_csv = []
    exported_json = []

    for table_name, df in payload.physical_tables.items():
        csv_path = csv_dir / f"{table_name}.csv"
        json_path = json_dir / f"{table_name}.json"

        df.to_csv(csv_path, index=False)
        df.to_json(json_path, orient="records", indent=2, force_ascii=False)

        exported_csv.append(csv_path)
        exported_json.append(json_path)

    return {
        "csv": exported_csv,
        "json": exported_json,
    }

# %%
# =========================================================
# BLOCO A1.3 — GERAR SCRIPT SQL PARA POSTGRESQL
# =========================================================

def build_postgres_create_table_sql(
    table_name: str,
    df: pd.DataFrame,
    primary_key: str | None = None
) -> str:
    """
    Gera um CREATE TABLE simples para PostgreSQL.
    """
    column_defs = []

    for col in df.columns:
        pg_type = infer_postgres_type(df[col])

        if primary_key is not None and col == primary_key:
            column_defs.append(f'    "{col}" {pg_type} PRIMARY KEY')
        else:
            column_defs.append(f'    "{col}" {pg_type}')

    sql = f'CREATE TABLE IF NOT EXISTS "{table_name}" (\n'
    sql += ",\n".join(column_defs)
    sql += "\n);\n"

    return sql


def build_postgres_insert_sql(table_name: str, df: pd.DataFrame) -> str:
    """
    Gera INSERTs simples para PostgreSQL.
    """
    columns_sql = ", ".join([f'"{col}"' for col in df.columns])

    lines = []
    for _, row in df.iterrows():
        values_sql = ", ".join([to_sql_literal(row[col]) for col in df.columns])
        lines.append(f'INSERT INTO "{table_name}" ({columns_sql}) VALUES ({values_sql});')

    return "\n".join(lines) + "\n"


def export_postgres_payload_sql(
    payload: PhysicalLoadBundle,
    output_dir: str | Path,
    primary_keys: dict[str, str] | None = None
) -> Path:
    """
    Exporta um único arquivo .sql contendo CREATE TABLE + INSERT.
    """
    if primary_keys is None:
        primary_keys = {}

    output_dir = ensure_dir(output_dir)
    sql_parts = []

    for table_name, df in payload.physical_tables.items():
        pk = primary_keys.get(table_name)

        sql_parts.append(f"-- ==================================================")
        sql_parts.append(f"-- TABLE: {table_name}")
        sql_parts.append(f"-- ==================================================\n")

        sql_parts.append(build_postgres_create_table_sql(table_name, df, primary_key=pk))
        sql_parts.append(build_postgres_insert_sql(table_name, df))
        sql_parts.append("\n")

    final_sql = "\n".join(sql_parts)

    out_path = output_dir / f"{payload.fragment_name}_postgres.sql"
    write_text_file(out_path, final_sql)
    return out_path

# %%
# =========================================================
# BLOCO A1.4 — GERAR SCRIPT CQL PARA CASSANDRA
# =========================================================

def build_cassandra_create_table_cql(
    table_name: str,
    df: pd.DataFrame,
    primary_key_clause: str
) -> str:
    """
    Gera um CREATE TABLE simples para Cassandra.

    primary_key_clause exemplos:
    - "PRIMARY KEY (user_id)"
    - "PRIMARY KEY (watchitem_id, person_id)"
    - "PRIMARY KEY ((genre_id, item_type), release_year, watchitem_id)"
    """
    column_defs = []

    for col in df.columns:
        cql_type = infer_cassandra_type(df[col])
        column_defs.append(f"    {col} {cql_type}")

    cql = f"CREATE TABLE IF NOT EXISTS {table_name} (\n"
    cql += ",\n".join(column_defs)
    cql += ",\n"
    cql += f"    {primary_key_clause}\n"
    cql += ");\n"

    return cql


def build_cassandra_insert_cql(table_name: str, df: pd.DataFrame) -> str:
    """
    Gera INSERTs simples para Cassandra.
    """
    columns_cql = ", ".join(df.columns.tolist())

    lines = []
    for _, row in df.iterrows():
        values_cql = ", ".join([to_cql_literal(row[col]) for col in df.columns])
        lines.append(f"INSERT INTO {table_name} ({columns_cql}) VALUES ({values_cql});")

    return "\n".join(lines) + "\n"


def export_cassandra_payload_cql(
    payload: PhysicalLoadBundle,
    output_dir: str | Path,
    primary_keys: dict[str, str]
) -> Path:
    """
    Exporta um arquivo .cql contendo CREATE TABLE + INSERT para Cassandra.
    """
    output_dir = ensure_dir(output_dir)
    cql_parts = []

    for table_name, df in payload.physical_tables.items():
        if table_name not in primary_keys:
            raise ValueError(
                f"Falta definir primary key para a tabela Cassandra '{table_name}'."
            )

        pk_clause = primary_keys[table_name]

        cql_parts.append(f"-- ==================================================")
        cql_parts.append(f"-- TABLE: {table_name}")
        cql_parts.append(f"-- ==================================================\n")

        cql_parts.append(build_cassandra_create_table_cql(table_name, df, pk_clause))
        cql_parts.append(build_cassandra_insert_cql(table_name, df))
        cql_parts.append("\n")

    final_cql = "\n".join(cql_parts)

    out_path = output_dir / f"{payload.fragment_name}_cassandra.cql"
    write_text_file(out_path, final_cql)
    return out_path

# %%
# =========================================================
# BLOCO A1.5 — EXECUTAR EXPORTAÇÃO COMPLETA
# =========================================================

# Checagens simples para evitar erro de ordem
required_names = [
    "user_payload",
    "content_payload",
]

for name in required_names:
    if name not in globals():
        raise NameError(
            f"'{name}' não está definido. Rode primeiro os blocos anteriores do payload físico."
        )

# Diretório-base de saída
EXPORT_BASE_DIR = ensure_dir("exports/imdb_hubara_manual")

# ---------------------------------------------------------
# 1) Exportar CSV/JSON
# ---------------------------------------------------------
user_files = export_bundle_to_csv_json(user_payload, EXPORT_BASE_DIR)
content_files = export_bundle_to_csv_json(content_payload, EXPORT_BASE_DIR)

print("Arquivos CSV/JSON exportados para UserFragment:")
for kind, paths in user_files.items():
    print(f"\n{kind.upper()}:")
    for p in paths:
        print(p)

print("\nArquivos CSV/JSON exportados para ContentFragment:")
for kind, paths in content_files.items():
    print(f"\n{kind.upper()}:")
    for p in paths:
        print(p)


# ---------------------------------------------------------
# 2) Exportar SQL PostgreSQL
# ---------------------------------------------------------
postgres_primary_keys = {
    "users": "user_id",
}

postgres_sql_path = export_postgres_payload_sql(
    payload=user_payload,
    output_dir=EXPORT_BASE_DIR / "sql",
    primary_keys=postgres_primary_keys
)

print("\nScript SQL gerado:")
print(postgres_sql_path)


# ---------------------------------------------------------
# 3) Exportar CQL Cassandra
# ---------------------------------------------------------
# Aqui definimos manualmente as primary keys iniciais.
# Isso é importante em Cassandra porque a modelagem física
# depende do padrão de acesso.
cassandra_primary_keys = {
    "persons": "PRIMARY KEY (person_id)",
    "genres": "PRIMARY KEY (genre_id)",
    "watchitems": "PRIMARY KEY (watchitem_id)",
    "movies": "PRIMARY KEY (watchitem_id)",
    "series": "PRIMARY KEY (watchitem_id)",
    "episodes": "PRIMARY KEY (watchitem_id)",
    "roles": "PRIMARY KEY (role_id)",
    "rates": "PRIMARY KEY (rate_id)",

    # tabelas orientadas ao workload
    "watchitems_by_title": "PRIMARY KEY (title, watchitem_id)",
    "persons_by_watchitem": "PRIMARY KEY (watchitem_id, role_type, person_id)",
    "watchitems_by_genre_type": "PRIMARY KEY ((genre_id, item_type), release_year, watchitem_id)",
}

cassandra_cql_path = export_cassandra_payload_cql(
    payload=content_payload,
    output_dir=EXPORT_BASE_DIR / "cql",
    primary_keys=cassandra_primary_keys
)

print("\nScript CQL gerado:")
print(cassandra_cql_path)
# Out:
# Arquivos CSV/JSON exportados para UserFragment:
#
# CSV:
# exports/imdb_hubara_manual/UserFragment/csv/users.csv
#
# JSON:
# exports/imdb_hubara_manual/UserFragment/json/users.json
#
# Arquivos CSV/JSON exportados para ContentFragment:
#
# CSV:
# exports/imdb_hubara_manual/ContentFragment/csv/persons.csv
# exports/imdb_hubara_manual/ContentFragment/csv/genres.csv
# exports/imdb_hubara_manual/ContentFragment/csv/watchitems.csv
# exports/imdb_hubara_manual/ContentFragment/csv/movies.csv
# exports/imdb_hubara_manual/ContentFragment/csv/series.csv
# exports/imdb_hubara_manual/ContentFragment/csv/episodes.csv
# exports/imdb_hubara_manual/ContentFragment/csv/roles.csv
# exports/imdb_hubara_manual/ContentFragment/csv/rates.csv
# exports/imdb_hubara_manual/ContentFragment/csv/watchitems_by_title.csv
# exports/imdb_hubara_manual/ContentFragment/csv/persons_by_watchitem.csv
# exports/imdb_hubara_manual/ContentFragment/csv/watchitems_by_genre_type.csv
#
# JSON:
# exports/imdb_hubara_manual/ContentFragment/json/persons.json
# exports/imdb_hubara_manual/ContentFragment/json/genres.json
# exports/imdb_hubara_manual/ContentFragment/json/watchitems.json
# exports/imdb_hubara_manual/ContentFragment/json/movies.json
# exports/imdb_hubara_manual/ContentFragment/json/series.json
# exports/imdb_hubara_manual/ContentFragment/json/episodes.json
# exports/imdb_hubara_manual/ContentFragment/json/roles.json
# exports/imdb_hubara_manual/ContentFragment/json/rates.json
# exports/imdb_hubara_manual/ContentFragment/json/watchitems_by_title.json
# exports/imdb_hubara_manual/ContentFragment/json/persons_by_watchitem.json
# exports/imdb_hubara_manual/ContentFragment/json/watchitems_by_genre_type.json
#
# Script SQL gerado:
# exports/imdb_hubara_manual/sql/UserFragment_postgres.sql
#
# Script CQL gerado:
# exports/imdb_hubara_manual/cql/ContentFragment_cassandra.cql

# %%
# =========================================================
# BLOCO A1.6 — INSPECIONAR OS SCRIPTS GERADOS
# =========================================================

print("Prévia do script PostgreSQL:\n")
print(Path(postgres_sql_path).read_text(encoding="utf-8")[:3000])

print("\n" + "=" * 80 + "\n")

print("Prévia do script Cassandra:\n")
print(Path(cassandra_cql_path).read_text(encoding="utf-8")[:4000])
# Out:
# Prévia do script PostgreSQL:
#
# -- ==================================================
# -- TABLE: users
# -- ==================================================
#
# CREATE TABLE IF NOT EXISTS "users" (
#     "user_id" BIGINT PRIMARY KEY,
#     "username" TEXT,
#     "password" TEXT,
#     "email" TEXT,
#     "last_login" TEXT
# );
#
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (1, 'user_1', 'pass_1', 'user_1@mail.com', '2026-01-02');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (2, 'user_2', 'pass_2', 'user_2@mail.com', '2026-01-03');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (3, 'user_3', 'pass_3', 'user_3@mail.com', '2026-01-04');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (4, 'user_4', 'pass_4', 'user_4@mail.com', '2026-01-05');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (5, 'user_5', 'pass_5', 'user_5@mail.com', '2026-01-06');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (6, 'user_6', 'pass_6', 'user_6@mail.com', '2026-01-07');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (7, 'user_7', 'pass_7', 'user_7@mail.com', '2026-01-08');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (8, 'user_8', 'pass_8', 'user_8@mail.com', '2026-01-09');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (9, 'user_9', 'pass_9', 'user_9@mail.com', '2026-01-10');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (10, 'user_10', 'pass_10', 'user_10@mail.com', '2026-01-11');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (11, 'user_11', 'pass_11', 'user_11@mail.com', '2026-01-12');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (12, 'user_12', 'pass_12', 'user_12@mail.com', '2026-01-13');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (13, 'user_13', 'pass_13', 'user_13@mail.com', '2026-01-14');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (14, 'user_14', 'pass_14', 'user_14@mail.com', '2026-01-15');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (15, 'user_15', 'pass_15', 'user_15@mail.com', '2026-01-16');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (16, 'user_16', 'pass_16', 'user_16@mail.com', '2026-01-17');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (17, 'user_17', 'pass_17', 'user_17@mail.com', '2026-01-18');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (18, 'user_18', 'pass_18', 'user_18@mail.com', '2026-01-19');
# INSERT INTO "users" ("user_id", "username", "password", "email", "last_login") VALUES (19,
#
# ================================================================================
#
# Prévia do script Cassandra:
#
# -- ==================================================
# -- TABLE: persons
# -- ==================================================
#
# CREATE TABLE IF NOT EXISTS persons (
#     person_id bigint,
#     name text,
#     date_of_birth text,
#     gender text,
#     PRIMARY KEY (person_id)
# );
#
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (1, 'Person 1', '1971-02-02', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (2, 'Person 2', '1972-03-03', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (3, 'Person 3', '1973-04-04', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (4, 'Person 4', '1974-05-05', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (5, 'Person 5', '1975-06-06', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (6, 'Person 6', '1976-07-07', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (7, 'Person 7', '1977-08-08', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (8, 'Person 8', '1978-09-09', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (9, 'Person 9', '1979-10-10', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (10, 'Person 10', '1980-11-11', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (11, 'Person 11', '1981-12-12', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (12, 'Person 12', '1982-01-13', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (13, 'Person 13', '1983-02-14', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (14, 'Person 14', '1984-03-15', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (15, 'Person 15', '1985-04-16', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (16, 'Person 16', '1986-05-17', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (17, 'Person 17', '1987-06-18', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (18, 'Person 18', '1988-07-19', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (19, 'Person 19', '1989-08-20', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (20, 'Person 20', '1990-09-21', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (21, 'Person 21', '1991-10-22', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (22, 'Person 22', '1992-11-23', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (23, 'Person 23', '1993-12-24', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (24, 'Person 24', '1994-01-25', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (25, 'Person 25', '1995-02-26', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (26, 'Person 26', '1996-03-27', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (27, 'Person 27', '1997-04-28', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (28, 'Person 28', '1998-05-01', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (29, 'Person 29', '1999-06-02', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (30, 'Person 30', '1970-07-03', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (31, 'Person 31', '1971-08-04', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (32, 'Person 32', '1972-09-05', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (33, 'Person 33', '1973-10-06', 'F');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (34, 'Person 34', '1974-11-07', 'M');
# INSERT INTO persons (person_id, name, date_of_birth, gender) VALUES (35, 'Person 35', '1975-12-08', 'F');
# INSERT INTO persons (person_id, na

# %%
pip install psycopg[binary] cassandra-driver
# Out:
# Collecting cassandra-driver
#   Downloading cassandra_driver-3.29.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting psycopg[binary]
#   Downloading psycopg-3.3.3-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: typing-extensions>=4.6 in /opt/conda/lib/python3.11/site-packages (from psycopg[binary]) (4.9.0)
# Collecting psycopg-binary==3.3.3 (from psycopg[binary])
#   Downloading psycopg_binary-3.3.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting geomet>=1.1 (from cassandra-driver)
#   Downloading geomet-1.1.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from geomet>=1.1->cassandra-driver) (8.1.7)
# Downloading psycopg_binary-3.3.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 41.6 MB/s eta 0:00:0000:0100:01
# Downloading cassandra_driver-3.29.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.3/374.3 kB 53.9 MB/s eta 0:00:00
# Downloading geomet-1.1.0-py3-none-any.whl (31 kB)
# Downloading psycopg-3.3.3-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.8/212.8 kB 38.4 MB/s eta 0:00:00
# Installing collected packages: psycopg-binary, psycopg, geomet, cassandra-driver
# Successfully installed cassandra-driver-3.29.3 geomet-1.1.0 psycopg-3.3.3 psycopg-binary-3.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# =========================================================
# BLOCO A2.1 — IMPORTS E FUNÇÕES UTILITÁRIAS
# =========================================================

from pathlib import Path
import re

# PostgreSQL
try:
    import psycopg
    HAS_PSYCOPG3 = True
except ImportError:
    HAS_PSYCOPG3 = False
    psycopg = None

# Cassandra
from cassandra.cluster import Cluster


def safe_identifier(name: str) -> str:
    """
    Garante que nomes como database_name e keyspace sejam simples e seguros.
    Aceita apenas letras, números e underscore, e não pode começar com número.
    """
    if not re.match(r"^[A-Za-z_][A-Za-z0-9_]*$", name):
        raise ValueError(f"Identificador inválido: {name}")
    return name


def strip_comment_lines(script_text: str) -> str:
    """
    Remove linhas que começam com '--'.
    Isso ajuda a executar scripts SQL/CQL statement por statement.
    """
    cleaned_lines = []
    for line in script_text.splitlines():
        stripped = line.strip()
        if stripped.startswith("--"):
            continue
        cleaned_lines.append(line)
    return "\n".join(cleaned_lines)


def split_script_statements(script_text: str) -> list[str]:
    """
    Divide um script em statements usando ';' como separador.
    Como nossos scripts são simples, isso é suficiente.
    """
    script_text = strip_comment_lines(script_text)
    parts = script_text.split(";")
    statements = []

    for part in parts:
        stmt = part.strip()
        if stmt:
            statements.append(stmt + ";")

    return statements

# %%
# =========================================================
# BLOCO A2.2 — POSTGRESQL: CRIAR DATABASE E EXECUTAR SCRIPT
# =========================================================

def pg_connect(dbname: str, spec: PhysicalDBSpec):
    """
    Abre conexão com PostgreSQL usando psycopg3.
    """
    if not HAS_PSYCOPG3:
        raise ImportError(
            "psycopg não está instalado. Rode: pip install psycopg[binary]"
        )

    conn = psycopg.connect(
        host=spec.host,
        port=spec.port,
        dbname=dbname,
        user=spec.username,
        password=spec.password,
        autocommit=True
    )
    return conn


def ensure_postgres_database_exists(spec: PhysicalDBSpec):
    """
    Cria o database alvo se ele ainda não existir.
    Conecta primeiro no database padrão 'postgres'.
    """
    target_db = safe_identifier(spec.database_name)

    with pg_connect("postgres", spec) as conn:
        with conn.cursor() as cur:
            cur.execute("SELECT 1 FROM pg_database WHERE datname = %s;", (target_db,))
            exists = cur.fetchone() is not None

            if not exists:
                cur.execute(f'CREATE DATABASE "{target_db}";')
                print(f"Database PostgreSQL criado: {target_db}")
            else:
                print(f"Database PostgreSQL já existe: {target_db}")


def execute_postgres_sql_script(spec: PhysicalDBSpec, sql_script_path: str | Path):
    """
    Executa um arquivo .sql statement por statement no database alvo.
    """
    sql_script_path = Path(sql_script_path)
    target_db = safe_identifier(spec.database_name)

    script_text = sql_script_path.read_text(encoding="utf-8")
    statements = split_script_statements(script_text)

    with pg_connect(target_db, spec) as conn:
        with conn.cursor() as cur:
            for stmt in statements:
                cur.execute(stmt)

    print(f"Script SQL executado com sucesso em PostgreSQL: {sql_script_path}")


def verify_postgres_table_counts(spec: PhysicalDBSpec, table_names: list[str]) -> pd.DataFrame:
    """
    Verifica quantidade de linhas por tabela no PostgreSQL.
    """
    rows = []
    target_db = safe_identifier(spec.database_name)

    with pg_connect(target_db, spec) as conn:
        with conn.cursor() as cur:
            for table_name in table_names:
                safe_table = safe_identifier(table_name)
                cur.execute(f'SELECT COUNT(*) FROM "{safe_table}";')
                count = cur.fetchone()[0]
                rows.append({
                    "table_name": table_name,
                    "row_count": count
                })

    return pd.DataFrame(rows)

# %%
# =========================================================
# BLOCO A2.3 — CASSANDRA: CRIAR KEYSPACE E EXECUTAR SCRIPT
# =========================================================

def cassandra_connect(spec: PhysicalDBSpec):
    """
    Abre conexão com Cassandra.
    """
    cluster = Cluster(contact_points=[spec.host], port=spec.port)
    session = cluster.connect()
    return cluster, session


def ensure_cassandra_keyspace_exists(spec: PhysicalDBSpec, replication_factor: int = 1):
    """
    Cria o keyspace alvo se ele ainda não existir.
    """
    keyspace = safe_identifier(spec.database_name)

    cluster, session = cassandra_connect(spec)
    try:
        cql = f"""
        CREATE KEYSPACE IF NOT EXISTS {keyspace}
        WITH replication = {{
            'class': 'SimpleStrategy',
            'replication_factor': {replication_factor}
        }};
        """
        session.execute(cql)
        print(f"Keyspace Cassandra garantido: {keyspace}")
    finally:
        session.shutdown()
        cluster.shutdown()


def execute_cassandra_cql_script(spec: PhysicalDBSpec, cql_script_path: str | Path):
    """
    Executa um arquivo .cql statement por statement no keyspace alvo.
    """
    cql_script_path = Path(cql_script_path)
    keyspace = safe_identifier(spec.database_name)

    script_text = cql_script_path.read_text(encoding="utf-8")
    statements = split_script_statements(script_text)

    cluster, session = cassandra_connect(spec)
    try:
        session.set_keyspace(keyspace)

        for stmt in statements:
            session.execute(stmt)

        print(f"Script CQL executado com sucesso em Cassandra: {cql_script_path}")
    finally:
        session.shutdown()
        cluster.shutdown()


def verify_cassandra_table_counts(spec: PhysicalDBSpec, table_names: list[str]) -> pd.DataFrame:
    """
    Verifica quantidade de linhas por tabela no Cassandra.
    Para o nosso caso inicial e dataset pequeno, SELECT COUNT(*) é aceitável.
    """
    keyspace = safe_identifier(spec.database_name)
    rows = []

    cluster, session = cassandra_connect(spec)
    try:
        session.set_keyspace(keyspace)

        for table_name in table_names:
            safe_table = safe_identifier(table_name)
            result = session.execute(f"SELECT COUNT(*) AS cnt FROM {safe_table};")
            count = result.one().cnt
            rows.append({
                "table_name": table_name,
                "row_count": count
            })
    finally:
        session.shutdown()
        cluster.shutdown()

    return pd.DataFrame(rows)

# %%
#para conectar no servidor remoto - rodar no terminal 
#ssh -N \
#  -L 55432:127.0.0.1:5432 \
#  -L 59042:127.0.0.1:9042 \
#  hudson@150.162.57.138
# Out:
# PostgreSQL: falha na conexão
# ConnectionTimeout connection timeout expired
# Cassandra: falha na conexão
# NoHostAvailable ('Unable to connect to any servers', {'150.162.57.138:9042': OSError(None, "Tried connecting to [('150.162.57.138', 9042)]. Last error: timed out")})

# %%
# =========================================================
# TESTE DE CONECTIVIDADE VIA SSH TUNNEL
# =========================================================

TUNNEL_HOST = "127.0.0.1"

# PostgreSQL
try:
    import psycopg
    conn = psycopg.connect(
        host=TUNNEL_HOST,
        port=55432,
        dbname="postgres",
        user="postgres",
        password="postgres",
        connect_timeout=5
    )
    conn.close()
    print("PostgreSQL via túnel: conexão OK")
except Exception as e:
    print("PostgreSQL via túnel: falha na conexão")
    print(type(e).__name__, e)

# Cassandra
try:
    from cassandra.cluster import Cluster
    cluster = Cluster(contact_points=[TUNNEL_HOST], port=59042)
    session = cluster.connect()
    session.shutdown()
    cluster.shutdown()
    print("Cassandra via túnel: conexão OK")
except Exception as e:
    print("Cassandra via túnel: falha na conexão")
    print(type(e).__name__, e)
# Out:
# PostgreSQL via túnel: conexão OK
# Cassandra via túnel: conexão OK

# %%
# =========================================================
# BLOCO A2.4 — EXECUTAR CARGA REAL NOS BANCOS
# =========================================================

required_names = [
    "hubara_imdb_materialization",
    "postgres_sql_path",
    "cassandra_cql_path",
    "user_payload",
    "content_payload",
]

for name in required_names:
    if name not in globals():
        raise NameError(
            f"'{name}' não está definido. Rode primeiro os blocos anteriores."
        )

# ---------------------------------------------------------
# 1) Recuperar specs físicos
# ---------------------------------------------------------
user_db_spec = hubara_imdb_materialization.fragment_to_db["UserFragment"]
content_db_spec = hubara_imdb_materialization.fragment_to_db["ContentFragment"]

print("User DB Spec:", user_db_spec)
print("Content DB Spec:", content_db_spec)

# ---------------------------------------------------------
# 2) Criar database PostgreSQL
# ---------------------------------------------------------
ensure_postgres_database_exists(user_db_spec)

# ---------------------------------------------------------
# 3) Criar keyspace Cassandra
# ---------------------------------------------------------
ensure_cassandra_keyspace_exists(content_db_spec, replication_factor=1)

# ---------------------------------------------------------
# 4) Executar script SQL no PostgreSQL
# ---------------------------------------------------------
execute_postgres_sql_script(user_db_spec, postgres_sql_path)

# ---------------------------------------------------------
# 5) Executar script CQL no Cassandra
# ---------------------------------------------------------
execute_cassandra_cql_script(content_db_spec, cassandra_cql_path)

print("\nCarga real finalizada.")
# Out:
# User DB Spec: PhysicalDBSpec(model='relational', engine='PostgreSQL', host='127.0.0.1', port=55432, database_name='imdb_user_db', username='postgres', password='postgres')
# Content DB Spec: PhysicalDBSpec(model='column', engine='Cassandra', host='127.0.0.1', port=59042, database_name='imdb_content_db', username=None, password=None)
# Database PostgreSQL criado: imdb_user_db
# Keyspace Cassandra garantido: imdb_content_db
# Script SQL executado com sucesso em PostgreSQL: exports/imdb_hubara_manual/sql/UserFragment_postgres.sql
# Script CQL executado com sucesso em Cassandra: exports/imdb_hubara_manual/cql/ContentFragment_cassandra.cql
#
# Carga real finalizada.

# %%
# =========================================================
# BLOCO A2.5 — VALIDAR CONTAGEM DAS TABELAS
# =========================================================

# PostgreSQL
postgres_tables = list(user_payload.physical_tables.keys())
postgres_counts_df = verify_postgres_table_counts(user_db_spec, postgres_tables)

print("Contagens no PostgreSQL:")
display(postgres_counts_df)

# Cassandra
cassandra_tables = list(content_payload.physical_tables.keys())
cassandra_counts_df = verify_cassandra_table_counts(content_db_spec, cassandra_tables)

print("Contagens no Cassandra:")
display(cassandra_counts_df)
# Out:
# Contagens no PostgreSQL:
#   table_name  row_count
# 0      users        100
# Contagens no Cassandra:
#                   table_name  row_count
# 0                    persons        120
# 1                     genres         10
# 2                 watchitems         80
# 3                     movies         34
# 4                     series         15
# 5                   episodes         31
# 6                      roles        290
# 7                      rates        547
# 8        watchitems_by_title         80
# 9       persons_by_watchitem        290
# 10  watchitems_by_genre_type         80

# %%
# =========================================================
# BLOCO B1 — FUNÇÕES DE BENCHMARK E ESTATÍSTICAS MELHORADAS
# =========================================================

import time
import random
import pandas as pd
import numpy as np


# ---------------------------------------------------------
# 1) Gerar parâmetros válidos para cada query
# ---------------------------------------------------------
def build_benchmark_parameter_pool(user_payload, content_payload, seed: int = 42):
    users_df = user_payload.physical_tables["users"]
    watchitems_df = content_payload.physical_tables["watchitems"]
    persons_by_watchitem_df = content_payload.physical_tables["persons_by_watchitem"]
    watchitems_by_genre_type_df = content_payload.physical_tables["watchitems_by_genre_type"]

    pool = {
        "Q1_Login": users_df["username"].tolist(),
        "Q2_SimpleSearch": watchitems_df["title"].tolist(),
        "Q4_Recommendation": watchitems_by_genre_type_df[
            ["genre_id", "item_type", "release_year"]
        ].drop_duplicates().to_dict(orient="records"),
        "Q5_AllPersonsOfTypeForWatchItem": persons_by_watchitem_df[
            ["watchitem_id", "role_type"]
        ].drop_duplicates().to_dict(orient="records"),
    }

    return pool


# ---------------------------------------------------------
# 2) Média sem extremos
# ---------------------------------------------------------
def trimmed_mean(values, trim_each_side: int = 1) -> float:
    """
    Remove os menores e maiores tempos antes de calcular a média.

    Exemplo:
    valores = [10, 11, 12, 13, 100]
    trim_each_side = 1
    remove 10 e 100 -> média de [11, 12, 13]
    """
    arr = np.array(values, dtype=float)

    if len(arr) == 0:
        return np.nan

    arr = np.sort(arr)

    # Se não houver dados suficientes para remover extremos,
    # cai para média normal.
    if len(arr) <= 2 * trim_each_side:
        return float(np.mean(arr))

    trimmed = arr[trim_each_side: len(arr) - trim_each_side]
    return float(np.mean(trimmed))


# ---------------------------------------------------------
# 3) Funções auxiliares para percentis
# ---------------------------------------------------------
def p95(x):
    return float(np.percentile(x, 95))

def p99(x):
    return float(np.percentile(x, 99))


# ---------------------------------------------------------
# 4) Resumo do benchmark com estatísticas extras
# ---------------------------------------------------------
def summarize_benchmark_results(
    result_df: pd.DataFrame,
    trim_each_side: int = 1,
    separate_by_phase: bool = True
) -> pd.DataFrame:
    """
    Gera estatísticas agregadas por query.
    Se separate_by_phase=True, separa cold e hot.
    """

    if result_df.empty:
        return pd.DataFrame()

    ok_df = result_df[result_df["success"] == True].copy()

    group_cols = ["query_name", "fragment_name", "db_engine"]
    if separate_by_phase:
        group_cols.append("benchmark_phase")

    # agregações básicas
    summary = (
        ok_df.groupby(group_cols, as_index=False)
        .agg(
            runs=("latency_ms", "count"),
            avg_ms=("latency_ms", "mean"),
            median_ms=("latency_ms", "median"),
            min_ms=("latency_ms", "min"),
            max_ms=("latency_ms", "max"),
            std_ms=("latency_ms", "std"),
            var_ms=("latency_ms", "var"),
            p95_ms=("latency_ms", p95),
            p99_ms=("latency_ms", p99),
        )
    )

    # std/var podem ficar NaN quando há só 1 execução
    summary["std_ms"] = summary["std_ms"].fillna(0.0)
    summary["var_ms"] = summary["var_ms"].fillna(0.0)

    # amplitude
    summary["range_ms"] = summary["max_ms"] - summary["min_ms"]

    # coeficiente de variação (%)
    # evita divisão por zero
    summary["cv_pct"] = np.where(
        summary["avg_ms"] > 0,
        (summary["std_ms"] / summary["avg_ms"]) * 100.0,
        np.nan
    )

    # média sem extremos
    trimmed_rows = []
    for keys, group in ok_df.groupby(group_cols):
        latencies = group["latency_ms"].tolist()
        trimmed_avg = trimmed_mean(latencies, trim_each_side=trim_each_side)

        if not isinstance(keys, tuple):
            keys = (keys,)

        row = dict(zip(group_cols, keys))
        row["avg_trimmed_ms"] = trimmed_avg
        trimmed_rows.append(row)

    trimmed_df = pd.DataFrame(trimmed_rows)

    summary = summary.merge(trimmed_df, on=group_cols, how="left")

    # ordenação final
    summary = summary.sort_values(group_cols).reset_index(drop=True)

    return summary

# %%
# =========================================================
# BLOCO B2 — ABRIR CONEXÕES DE BENCHMARK
# =========================================================

# Reusa funções já criadas antes:
# - pg_connect(...)
# - cassandra_connect(...)

def open_benchmark_connections(user_db_spec, content_db_spec):
    """
    Abre conexões persistentes para o benchmark.
    """
    pg_conn = pg_connect(user_db_spec.database_name, user_db_spec)
    pg_conn.autocommit = True

    cass_cluster, cass_session = cassandra_connect(content_db_spec)
    cass_session.set_keyspace(content_db_spec.database_name)

    return pg_conn, cass_cluster, cass_session


def close_benchmark_connections(pg_conn, cass_cluster, cass_session):
    """
    Fecha tudo de forma limpa.
    """
    try:
        if pg_conn is not None:
            pg_conn.close()
    except Exception:
        pass

    try:
        if cass_session is not None:
            cass_session.shutdown()
    except Exception:
        pass

    try:
        if cass_cluster is not None:
            cass_cluster.shutdown()
    except Exception:
        pass

# %%
# =========================================================
# BLOCO B3 — EXECUÇÃO REAL DAS QUERIES DO WORKLOAD
# =========================================================

# ---------------------------------------------------------
# Q1 — Login (PostgreSQL)
# RETURN password FROM User WHERE username = ?
# ---------------------------------------------------------
def run_q1_login_postgres(pg_conn, username: str):
    sql = """
    SELECT password
    FROM users
    WHERE username = %s
    LIMIT 1;
    """
    with pg_conn.cursor() as cur:
        cur.execute(sql, (username,))
        return cur.fetchone()


# ---------------------------------------------------------
# Q2 — Simple search (Cassandra)
# RETURN ALL FROM WatchItem WHERE title = ?
# ---------------------------------------------------------
def run_q2_simple_search_cassandra(cass_session, title: str):
    cql = """
    SELECT *
    FROM watchitems_by_title
    WHERE title = %s;
    """
    return list(cass_session.execute(cql, (title,)))


# ---------------------------------------------------------
# Q3 — Add entities and relationships (Cassandra)
# Inserimos:
# - uma nova pessoa em persons
# - um novo vínculo em roles ligando a pessoa a um watchitem existente
#
# Isso representa bem a ideia de:
# "Insert Person ... connect Person with WatchItem"
# ---------------------------------------------------------
def run_q3_add_entities_and_relationships_cassandra(
    cass_session,
    person_id: int,
    person_name: str,
    birth_date: str,
    gender: str,
    role_id: int,
    watchitem_id: int,
    role_type: str
):
    insert_person_cql = """
    INSERT INTO persons (person_id, name, date_of_birth, gender)
    VALUES (%s, %s, %s, %s);
    """

    insert_role_cql = """
    INSERT INTO roles (role_id, person_id, watchitem_id, role_type)
    VALUES (%s, %s, %s, %s);
    """

    cass_session.execute(insert_person_cql, (person_id, person_name, birth_date, gender))
    cass_session.execute(insert_role_cql, (role_id, person_id, watchitem_id, role_type))

    return True


# ---------------------------------------------------------
# Q4 — Recommendation query (Cassandra)
# Usamos a tabela orientada ao workload:
# watchitems_by_genre_type
#
# Consulta:
# - genre_id
# - item_type
# - faixa de release_year
# ---------------------------------------------------------
def run_q4_recommendation_cassandra(
    cass_session,
    genre_id: int,
    item_type: str,
    year_low: int,
    year_high: int
):
    cql = """
    SELECT *
    FROM watchitems_by_genre_type
    WHERE genre_id = %s
      AND item_type = %s
      AND release_year >= %s
      AND release_year <= %s;
    """
    return list(cass_session.execute(cql, (genre_id, item_type, year_low, year_high)))


# ---------------------------------------------------------
# Q5 — All persons of type for a watch item (Cassandra)
# persons_by_watchitem WHERE watchitem_id = ? AND role_type = ?
# ---------------------------------------------------------
def run_q5_all_persons_for_watchitem_cassandra(
    cass_session,
    watchitem_id: int,
    role_type: str
):
    cql = """
    SELECT *
    FROM persons_by_watchitem
    WHERE watchitem_id = %s
      AND role_type = %s;
    """
    return list(cass_session.execute(cql, (watchitem_id, role_type)))

# %%
# =========================================================
# BLOCO B4 — EXECUTOR COMPLETO DO BENCHMARK COM COLD/HOT
# =========================================================

def run_hubara_imdb_benchmark(
    user_db_spec,
    content_db_spec,
    user_payload,
    content_payload,
    cold_repetitions: int = 3,
    hot_repetitions: int = 20,
    seed: int = 42
) -> BenchmarkResult:

    rng = random.Random(seed)
    parameter_pool = build_benchmark_parameter_pool(user_payload, content_payload, seed=seed)

    max_person_id = int(content_payload.physical_tables["persons"]["person_id"].max())
    max_role_id = int(content_payload.physical_tables["roles"]["role_id"].max())
    available_watchitem_ids = content_payload.physical_tables["watchitems"]["watchitem_id"].tolist()

    benchmark_result = BenchmarkResult(
        scenario_name="IMDb",
        recommendation_name="Hubara_IMDb_Recommendation"
    )

    def append_result(query_name, fragment_name, db_engine, run_id, benchmark_phase, start_time, success, error_message):
        latency_ms = (time.perf_counter() - start_time) * 1000.0
        benchmark_result.query_results.append(
            QueryExecutionResult(
                query_name=query_name,
                fragment_name=fragment_name,
                db_engine=db_engine,
                run_id=run_id,
                benchmark_phase=benchmark_phase,
                latency_ms=latency_ms,
                success=success,
                error_message=error_message,
            )
        )

    # -----------------------------------------------------
    # COLD RUNS
    # -----------------------------------------------------

    # Q1 — PostgreSQL
    for run_id in range(1, cold_repetitions + 1):
        username = rng.choice(parameter_pool["Q1_Login"])
        start = time.perf_counter()
        success = True
        error_message = None

        pg_conn = None
        try:
            pg_conn = pg_connect(user_db_spec.database_name, user_db_spec)
            pg_conn.autocommit = True
            _ = run_q1_login_postgres(pg_conn, username)
        except Exception as e:
            success = False
            error_message = str(e)
        finally:
            if pg_conn is not None:
                pg_conn.close()

        append_result("Q1_Login", "UserFragment", "PostgreSQL", run_id, "cold", start, success, error_message)

    # Q2 — Cassandra
    for run_id in range(1, cold_repetitions + 1):
        title = rng.choice(parameter_pool["Q2_SimpleSearch"])
        start = time.perf_counter()
        success = True
        error_message = None

        cass_cluster, cass_session = None, None
        try:
            cass_cluster, cass_session = cassandra_connect(content_db_spec)
            cass_session.set_keyspace(content_db_spec.database_name)
            _ = run_q2_simple_search_cassandra(cass_session, title)
        except Exception as e:
            success = False
            error_message = str(e)
        finally:
            close_benchmark_connections(None, cass_cluster, cass_session)

        append_result("Q2_SimpleSearch", "ContentFragment", "Cassandra", run_id, "cold", start, success, error_message)

    # Q3 — Cassandra
    for run_id in range(1, cold_repetitions + 1):
        person_id = max_person_id + run_id
        role_id = max_role_id + run_id
        watchitem_id = rng.choice(available_watchitem_ids)
        person_name = f"Benchmark Person Cold {person_id}"
        birth_date = "1990-01-01"
        gender = "M"
        role_type = rng.choice(["Actor", "Director", "Producer"])

        start = time.perf_counter()
        success = True
        error_message = None

        cass_cluster, cass_session = None, None
        try:
            cass_cluster, cass_session = cassandra_connect(content_db_spec)
            cass_session.set_keyspace(content_db_spec.database_name)
            _ = run_q3_add_entities_and_relationships_cassandra(
                cass_session, person_id, person_name, birth_date, gender,
                role_id, watchitem_id, role_type
            )
        except Exception as e:
            success = False
            error_message = str(e)
        finally:
            close_benchmark_connections(None, cass_cluster, cass_session)

        append_result("Q3_AddEntitiesAndRelationships", "ContentFragment", "Cassandra", run_id, "cold", start, success, error_message)

    # Q4 — Cassandra
    for run_id in range(1, cold_repetitions + 1):
        row = rng.choice(parameter_pool["Q4_Recommendation"])
        genre_id = int(row["genre_id"])
        item_type = row["item_type"]
        center_year = int(row["release_year"])
        year_low = center_year - 10
        year_high = center_year + 10

        start = time.perf_counter()
        success = True
        error_message = None

        cass_cluster, cass_session = None, None
        try:
            cass_cluster, cass_session = cassandra_connect(content_db_spec)
            cass_session.set_keyspace(content_db_spec.database_name)
            _ = run_q4_recommendation_cassandra(
                cass_session, genre_id, item_type, year_low, year_high
            )
        except Exception as e:
            success = False
            error_message = str(e)
        finally:
            close_benchmark_connections(None, cass_cluster, cass_session)

        append_result("Q4_Recommendation", "ContentFragment", "Cassandra", run_id, "cold", start, success, error_message)

    # Q5 — Cassandra
    for run_id in range(1, cold_repetitions + 1):
        row = rng.choice(parameter_pool["Q5_AllPersonsOfTypeForWatchItem"])
        watchitem_id = int(row["watchitem_id"])
        role_type = row["role_type"]

        start = time.perf_counter()
        success = True
        error_message = None

        cass_cluster, cass_session = None, None
        try:
            cass_cluster, cass_session = cassandra_connect(content_db_spec)
            cass_session.set_keyspace(content_db_spec.database_name)
            _ = run_q5_all_persons_for_watchitem_cassandra(
                cass_session, watchitem_id, role_type
            )
        except Exception as e:
            success = False
            error_message = str(e)
        finally:
            close_benchmark_connections(None, cass_cluster, cass_session)

        append_result("Q5_AllPersonsOfTypeForWatchItem", "ContentFragment", "Cassandra", run_id, "cold", start, success, error_message)

    # -----------------------------------------------------
    # HOT RUNS
    # -----------------------------------------------------
    pg_conn, cass_cluster, cass_session = open_benchmark_connections(user_db_spec, content_db_spec)

    try:
        # Q1 — PostgreSQL
        for run_id in range(1, hot_repetitions + 1):
            username = rng.choice(parameter_pool["Q1_Login"])
            start = time.perf_counter()
            success = True
            error_message = None

            try:
                _ = run_q1_login_postgres(pg_conn, username)
            except Exception as e:
                success = False
                error_message = str(e)

            append_result("Q1_Login", "UserFragment", "PostgreSQL", run_id, "hot", start, success, error_message)

        # Q2 — Cassandra
        for run_id in range(1, hot_repetitions + 1):
            title = rng.choice(parameter_pool["Q2_SimpleSearch"])
            start = time.perf_counter()
            success = True
            error_message = None

            try:
                _ = run_q2_simple_search_cassandra(cass_session, title)
            except Exception as e:
                success = False
                error_message = str(e)

            append_result("Q2_SimpleSearch", "ContentFragment", "Cassandra", run_id, "hot", start, success, error_message)

        # Q3 — Cassandra
        for run_id in range(1, hot_repetitions + 1):
            person_id = max_person_id + cold_repetitions + run_id
            role_id = max_role_id + cold_repetitions + run_id
            watchitem_id = rng.choice(available_watchitem_ids)
            person_name = f"Benchmark Person Hot {person_id}"
            birth_date = "1990-01-01"
            gender = "M"
            role_type = rng.choice(["Actor", "Director", "Producer"])

            start = time.perf_counter()
            success = True
            error_message = None

            try:
                _ = run_q3_add_entities_and_relationships_cassandra(
                    cass_session, person_id, person_name, birth_date, gender,
                    role_id, watchitem_id, role_type
                )
            except Exception as e:
                success = False
                error_message = str(e)

            append_result("Q3_AddEntitiesAndRelationships", "ContentFragment", "Cassandra", run_id, "hot", start, success, error_message)

        # Q4 — Cassandra
        for run_id in range(1, hot_repetitions + 1):
            row = rng.choice(parameter_pool["Q4_Recommendation"])
            genre_id = int(row["genre_id"])
            item_type = row["item_type"]
            center_year = int(row["release_year"])
            year_low = center_year - 10
            year_high = center_year + 10

            start = time.perf_counter()
            success = True
            error_message = None

            try:
                _ = run_q4_recommendation_cassandra(
                    cass_session, genre_id, item_type, year_low, year_high
                )
            except Exception as e:
                success = False
                error_message = str(e)

            append_result("Q4_Recommendation", "ContentFragment", "Cassandra", run_id, "hot", start, success, error_message)

        # Q5 — Cassandra
        for run_id in range(1, hot_repetitions + 1):
            row = rng.choice(parameter_pool["Q5_AllPersonsOfTypeForWatchItem"])
            watchitem_id = int(row["watchitem_id"])
            role_type = row["role_type"]

            start = time.perf_counter()
            success = True
            error_message = None

            try:
                _ = run_q5_all_persons_for_watchitem_cassandra(
                    cass_session, watchitem_id, role_type
                )
            except Exception as e:
                success = False
                error_message = str(e)

            append_result("Q5_AllPersonsOfTypeForWatchItem", "ContentFragment", "Cassandra", run_id, "hot", start, success, error_message)

    finally:
        close_benchmark_connections(pg_conn, cass_cluster, cass_session)

    return benchmark_result

# %%
# =========================================================
# BLOCO B5 — RODAR BENCHMARK, RESUMIR E EXPORTAR CSV
# =========================================================

# Ajuste esses números como quiser
COLD_REPETITIONS = 3
HOT_REPETITIONS = 20
TRIM_EACH_SIDE = 1

benchmark_result = run_hubara_imdb_benchmark(
    user_db_spec=user_db_spec,
    content_db_spec=content_db_spec,
    user_payload=user_payload,
    content_payload=content_payload,
    cold_repetitions=COLD_REPETITIONS,
    hot_repetitions=HOT_REPETITIONS,
    seed=42
)

benchmark_df = benchmark_result.to_dataframe()

summary_df = summarize_benchmark_results(
    benchmark_df,
    trim_each_side=TRIM_EACH_SIDE,
    separate_by_phase=True
)

failures_df = benchmark_df[benchmark_df["success"] == False].copy()

print("Resultados brutos do benchmark:")
display(benchmark_df.head(30))

print("Resumo estatístico do benchmark:")
display(summary_df)

print("Falhas, se existirem:")
display(failures_df)

# ---------------------------------------------------------
# Exportar resultados para CSV
# ---------------------------------------------------------
from pathlib import Path

results_dir = Path("exports/benchmark_results")
results_dir.mkdir(parents=True, exist_ok=True)

raw_csv_path = results_dir / "hubara_imdb_benchmark_raw.csv"
summary_csv_path = results_dir / "hubara_imdb_benchmark_summary.csv"
failures_csv_path = results_dir / "hubara_imdb_benchmark_failures.csv"

benchmark_df.to_csv(raw_csv_path, index=False)
summary_df.to_csv(summary_csv_path, index=False)
failures_df.to_csv(failures_csv_path, index=False)

print("\nArquivos CSV gerados:")
print(raw_csv_path)
print(summary_csv_path)
print(failures_csv_path)
# Out:
# Resultados brutos do benchmark:
#    scenario_name         recommendation_name                       query_name  \
# 0           IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 1           IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 2           IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 3           IMDb  Hubara_IMDb_Recommendation                  Q2_SimpleSearch
# 4           IMDb  Hubara_IMDb_Recommendation                  Q2_SimpleSearch
# 5           IMDb  Hubara_IMDb_Recommendation                  Q2_SimpleSearch
# 6           IMDb  Hubara_IMDb_Recommendation   Q3_AddEntitiesAndRelationships
# 7           IMDb  Hubara_IMDb_Recommendation   Q3_AddEntitiesAndRelationships
# 8           IMDb  Hubara_IMDb_Recommendation   Q3_AddEntitiesAndRelationships
# 9           IMDb  Hubara_IMDb_Recommendation                Q4_Recommendation
# 10          IMDb  Hubara_IMDb_Recommendation                Q4_Recommendation
# 11          IMDb  Hubara_IMDb_Recommendation                Q4_Recommendation
# 12          IMDb  Hubara_IMDb_Recommendation  Q5_AllPersonsOfTypeForWatchItem
# 13          IMDb  Hubara_IMDb_Recommendation  Q5_AllPersonsOfTypeForWatchItem
# 14          IMDb  Hubara_IMDb_Recommendation  Q5_AllPersonsOfTypeForWatchItem
# 15          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 16          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 17          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 18          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 19          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 20          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 21          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 22          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 23          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 24          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 25          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 26          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 27          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 28          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
# 29          IMDb  Hubara_IMDb_Recommendation                         Q1_Login
#
#       fragment_name   db_engine  run_id benchmark_phase  latency_ms  success  \
# 0      UserFragment  PostgreSQL       1            cold   19.992073     True
# 1      UserFragment  PostgreSQL       2            cold   12.820249     True
# 2      UserFragment  PostgreSQL       3            cold   13.463467     True
# 3   ContentFragment   Cassandra       1            cold   62.209104     True
# 4   ContentFragment   Cassandra       2            cold   51.550290     True
# 5   ContentFragment   Cassandra       3            cold   50.114363     True
# 6   ContentFragment   Cassandra       1            cold   53.137088     True
# 7   ContentFragment   Cassandra       2            cold   51.105374     True
# 8   ContentFragment   Cassandra       3            cold   55.396635     True
# 9   ContentFragment   Cassandra       1            cold   53.736225    False
# 10  ContentFragment   Cassandra       2            cold   54.927959    False
# 11  ContentFragment   Cassandra       3            cold   47.913968    False
# 12  ContentFragment   Cassandra       1            cold   58.864765     True
# 13  ContentFragment   Cassandra       2            cold   61.489385     True
# 14  ContentFragment   Cassandra       3            cold   58.902556     True
# 15     UserFragment  PostgreSQL       1             hot    2.061824     True
# 16     UserFragment  PostgreSQL       2             hot    0.902561     True
# 17     UserFragment  PostgreSQL       3             hot    0.935051     True
# 18     UserFragment  PostgreSQL       4             hot    0.919450     True
# 19     UserFragment  PostgreSQL       5             hot    0.818190     True
# 20     UserFragment  PostgreSQL       6             hot    1.906642     True
# 21     UserFragment  PostgreSQL       7             hot    1.116223     True
# 22     UserFragment  PostgreSQL       8             hot    1.479177     True
# 23     UserFragment  PostgreSQL       9             hot    0.858280     True
# 24     UserFragment  PostgreSQL      10             hot    0.868140     True
# 25     UserFragment  PostgreSQL      11             hot    0.820519     True
# 26     UserFragment  PostgreSQL      12             hot    1.227795     True
# 27     UserFragment  PostgreSQL      13             hot    1.078812     True
# 28     UserFragment  PostgreSQL      14             hot    0.718689     True
# 29     UserFragment  PostgreSQL      15             hot    0.650167     True
#
#                                         error_message
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9   <Error from server: code=2000 [Syntax error in...
# 10  <Error from server: code=2000 [Syntax error in...
# 11  <Error from server: code=2000 [Syntax error in...
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# Resumo estatístico do benchmark:
#                         query_name    fragment_name   db_engine  \
# 0                         Q1_Login     UserFragment  PostgreSQL
# 1                         Q1_Login     UserFragment  PostgreSQL
# 2                  Q2_SimpleSearch  ContentFragment   Cassandra
# 3                  Q2_SimpleSearch  ContentFragment   Cassandra
# 4   Q3_AddEntitiesAndRelationships  ContentFragment   Cassandra
# 5   Q3_AddEntitiesAndRelationships  ContentFragment   Cassandra
# 6  Q5_AllPersonsOfTypeForWatchItem  ContentFragment   Cassandra
# 7  Q5_AllPersonsOfTypeForWatchItem  ContentFragment   Cassandra
#
#   benchmark_phase  runs     avg_ms  median_ms     min_ms     max_ms    std_ms  \
# 0            cold     3  15.425263  13.463467  12.820249  19.992073  3.968028
# 1             hot    20   1.017602   0.901231   0.650167   2.061824  0.384734
# 2            cold     3  54.624586  51.550290  50.114363  62.209104  6.607508
# 3             hot    20   2.574746   2.538030   1.657599   4.351671  0.668214
# 4            cold     3  53.213032  53.137088  51.105374  55.396635  2.146638
# 5             hot    20   2.788440   2.635185   1.766461   4.201029  0.765436
# 6            cold     3  59.752235  58.902556  58.864765  61.489385  1.504534
# 7             hot    20   1.977854   1.805230   1.256154   3.766204  0.547680
#
#       var_ms     p95_ms     p99_ms   range_ms     cv_pct  avg_trimmed_ms
# 0  15.745248  19.339212  19.861501   7.171824  25.724217       13.463467
# 1   0.148020   1.914401   2.032339   1.411657  37.807930        0.980003
# 2  43.659160  61.143223  61.995928  12.094741  12.096216       51.550290
# 3   0.446510   3.821697   4.245676   2.694072  25.952616        2.526981
# 4   4.608056  55.170680  55.351444   4.291261   4.034046       53.137088
# 5   0.585892   4.155990   4.192021   2.434568  27.450324        2.766739
# 6   2.263624  61.230702  61.437648   2.624620   2.517955       58.902556
# 7   0.299953   2.814009   3.575765   2.510050  27.690618        1.918595
# Falhas, se existirem:
#    scenario_name         recommendation_name         query_name  \
# 9           IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 10          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 11          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 75          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 76          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 77          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 78          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 79          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 80          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 81          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 82          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 83          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 84          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 85          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 86          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 87          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 88          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 89          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 90          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 91          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 92          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 93          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
# 94          IMDb  Hubara_IMDb_Recommendation  Q4_Recommendation
#
#       fragment_name  db_engine  run_id benchmark_phase  latency_ms  success  \
# 9   ContentFragment  Cassandra       1            cold   53.736225    False
# 10  ContentFragment  Cassandra       2            cold   54.927959    False
# 11  ContentFragment  Cassandra       3            cold   47.913968    False
# 75  ContentFragment  Cassandra       1             hot    1.258584    False
# 76  ContentFragment  Cassandra       2             hot    1.301895    False
# 77  ContentFragment  Cassandra       3             hot    1.761040    False
# 78  ContentFragment  Cassandra       4             hot    0.995392    False
# 79  ContentFragment  Cassandra       5             hot    1.026042    False
# 80  ContentFragment  Cassandra       6             hot    1.387466    False
# 81  ContentFragment  Cassandra       7             hot    1.004442    False
# 82  ContentFragment  Cassandra       8             hot    1.480117    False
# 83  ContentFragment  Cassandra       9             hot    1.296505    False
# 84  ContentFragment  Cassandra      10             hot    1.279345    False
# 85  ContentFragment  Cassandra      11             hot    0.819529    False
# 86  ContentFragment  Cassandra      12             hot    1.167733    False
# 87  ContentFragment  Cassandra      13             hot    1.159164    False
# 88  ContentFragment  Cassandra      14             hot    2.126794    False
# 89  ContentFragment  Cassandra      15             hot    1.156823    False
# 90  ContentFragment  Cassandra      16             hot    1.063422    False
# 91  ContentFragment  Cassandra      17             hot    1.169073    False
# 92  ContentFragment  Cassandra      18             hot    1.364776    False
# 93  ContentFragment  Cassandra      19             hot    0.850560    False
# 94  ContentFragment  Cassandra      20             hot    1.480577    False
#
#                                         error_message
# 9   <Error from server: code=2000 [Syntax error in...
# 10  <Error from server: code=2000 [Syntax error in...
# 11  <Error from server: code=2000 [Syntax error in...
# 75  <Error from server: code=2000 [Syntax error in...
# 76  <Error from server: code=2000 [Syntax error in...
# 77  <Error from server: code=2000 [Syntax error in...
# 78  <Error from server: code=2000 [Syntax error in...
# 79  <Error from server: code=2000 [Syntax error in...
# 80  <Error from server: code=2000 [Syntax error in...
# 81  <Error from server: code=2000 [Syntax error in...
# 82  <Error from server: code=2000 [Syntax error in...
# 83  <Error from server: code=2000 [Syntax error in...
# 84  <Error from server: code=2000 [Syntax error in...
# 85  <Error from server: code=2000 [Syntax error in...
# 86  <Error from server: code=2000 [Syntax error in...
# 87  <Error from server: code=2000 [Syntax error in...
# 88  <Error from server: code=2000 [Syntax error in...
# 89  <Error from server: code=2000 [Syntax error in...
# 90  <Error from server: code=2000 [Syntax error in...
# 91  <Error from server: code=2000 [Syntax error in...
# 92  <Error from server: code=2000 [Syntax error in...
# 93  <Error from server: code=2000 [Syntax error in...
# 94  <Error from server: code=2000 [Syntax error in...
# Arquivos CSV gerados:
# exports/benchmark_results/hubara_imdb_benchmark_raw.csv
# exports/benchmark_results/hubara_imdb_benchmark_summary.csv
# exports/benchmark_results/hubara_imdb_benchmark_failures.csv
